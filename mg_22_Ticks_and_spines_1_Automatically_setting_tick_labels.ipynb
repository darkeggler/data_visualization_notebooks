# %% [markdown]
# # 22_Ticks_and_spines_1_Automatically_setting_tick_labels
# [官网](https://matplotlib.org/gallery/ticks_and_spines/auto_ticks.html#sphx-glr-gallery-ticks-and-spines-auto-ticks-py)
#
# ```python
# #axes.autolimit_mode: data  # How to scale axes limits to the data.  By using:
#                             #     - "data" to use data limits, plus some margin
#                             #     - "round_numbers" move to the nearest "round" number
# #axes.xmargin:   .05  # x margin.  See `axes.Axes.margins`
# #axes.ymargin:   .05  # y margin.  See `axes.Axes.margins`
# ```
# evenly-distributed  均匀分布

# %% [markdown]
# 设置matplotlib自动安排轴刻度的行为。
#
# 如果没有明确的设置刻度的位置与标签，matplotlib将尝试根据显示的数据及其限制自动选择它们。
#
# 默认情况下，这会尝试选择沿轴分布的刻度位置：

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(19680801)

fig, ax = plt.subplots()
dots = np.arange(10) / 100. + .03
x, y = np.meshgrid(dots, dots)
data = [x.ravel(), y.ravel()]
ax.scatter(*data, c=data[1])

# %% [markdown]
# 有时，选择均匀分布的刻度会导致奇怪的刻度值。如果想要Matplotlib保持刻度位置在整数，改变rcParams值

# %%
print(plt.rcParams['axes.autolimit_mode'])

# Now change this value and see the results
with plt.rc_context({'axes.autolimit_mode': 'round_numbers'}):
    fig, ax = plt.subplots()
    ax.scatter(*data, c=data[1])
# Out:
# data

# %% [markdown]
# You can also alter the margins of the axes around the data by with axes.(x,y)margin:
#
# 两边的留白被称为 margin

# %%
with plt.rc_context({'axes.autolimit_mode': 'round_numbers',
                     'axes.xmargin': .8,
                     'axes.ymargin': .8}):
    fig, ax = plt.subplots()
    ax.scatter(*data, c=data[1])

plt.show()

# %% [markdown]
# matplotlib.axes.Axes.set_xmargin也可以做到

# %% [markdown]
# **小结**

# %% [markdown]
# **问题**
# rcParams['axes.autolimit_mode']在Axes中出现吗？这个参数在什么时候被使用？

# %% [markdown]
# **扩展**
# [Numpy Meshgrid function](https://www.geeksforgeeks.org/numpy-meshgrid-function/#:~:text=The%20numpy.meshgrid%20function%20is%20used%20to%20create%20a,4%20and%20Y-axis%20ranging%20from%20-5%20to%205.)
# [numpy.meshgrid](https://numpy.org/doc/stable/reference/generated/numpy.meshgrid.html)
