# %% [markdown]
# mg_22_Ticks_and_spines_2_Centering_labels_between_ticks

# %%
import matplotlib.cbook as cbook
import matplotlib.pyplot as plt

import numpy as np

# %%
r = (cbook.get_sample_data('aapl.npz', np_load=True)['price_data']
     .view(np.recarray))

# %%
r = r[-250:]

# %%
fig, ax = plt.subplots()
ax.plot(r.date, r.adj_close)

# %%
print(ax.xaxis)
# Out:
# XAxis(54.0,36.0)

# %%
type(ax.xaxis).__name__
# Out:
# 'XAxis'

# %%
ax.xaxis.cla()

# %%
fig

# %% [markdown]
# [matplotlib.axis.Axis.set_major_locator](https://matplotlib.org/api/_as_gen/matplotlib.axis.Axis.set_major_locator.html#matplotlib.axis.Axis.set_major_locator)
