# %% [markdown]
# # matplotlib 20题

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
matplotlib.rcParams['font.family'] = ['DengXian', 'Sans-serif'] #为了中文

# %%
t = np.arange(0.01, 5.0, 0.2)
s = np.exp(t)
f = r'e:\notebooks\png\0'

# %% [markdown]
# 1. 画出以下图形

# %%
plt.plot(t,s)

# %%
fig, ax = plt.subplots()
ax.plot(s)

# %%
fig.savefig(f + '01.png')

# %% [markdown]
# 2. 画出以下图形

# %%
plt.plot(s,'ro')

# %%
ax.cla()

# %%
ax.plot(s,'ro')

# %%
fig.savefig(f + '02.png')
